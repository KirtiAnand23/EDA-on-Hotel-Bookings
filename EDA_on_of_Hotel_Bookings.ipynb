# %% [markdown]
# <a href="https://colab.research.google.com/github/KirtiAnand23/EDA-on-Hotel-Bookings/blob/main/EDA_on_of_Hotel_Bookings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ##### <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ##### <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# I explored and analyzed the given dataset and discovered some important factors regarding hotel booking. For this, I first read the given data in my collab notebook and then understand the whole data like what are variables in the given data. After that cleaned the data frame in data wrangling. For that I used some functions like drop(), fillna(), isna()/isnull() functions. Then I added some columns which are required in the analysis and removed some columns which are not required. Using this data frame I explored some variables using visualization charts like pie charts, count plots, barplot, and heatmaps and I can find out some insights which are important factors.The main few things I will usually consider include prices per night, distance of hotel from attractions and restaurants, availability of free breakfasts, scenery in hotel room, cleaniness of hotel room and of course, availability of free wifi. In this dataset, we ae able to know different types of bookings (i.e type of hotel, duration of stay, types of visitors, types of booking, etc). From these insights, I can suggest some business objectives to clients.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/KirtiAnand23/EDA-on-Hotel-Bookings

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The cancellation rates of hotel bookings are higher,negatively impacting revenue growth of hotels.The purpose of this research is to examine proactive engagement plans to increase revenue of hotels decreasing cancellations rates.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ***Main objective is to identify key trends and patterns in the data that can be used to improve business strategies in the hotel industry***
#
# **Understanding the travel patterns and preferences of their guests is important for hotels in order to make informed decisions about things like peak seasons, common reasons for cancellations, demand for amenities such as parking, and the number of children staying at the property. For many people, travelling is a thrilling and meaningful experience.**

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Capstone Project on HOTEL BOOKING ANALYSIS/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87392 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_values = df.duplicated().value_counts()
duplicate_values
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# Removing duplicate records from dataset
df.drop_duplicates(inplace = True)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = df.isnull().sum().sort_values(ascending=0)

df_mv = pd.DataFrame({'Categories':missing_values.index, 'Total_count':missing_values.values})
df_mv
# Out:
#                         Categories  Total_count
# 0                          company        82137
# 1                            agent        12193
# 2                          country          452
# 3                         children            4
# 4               reserved_room_type            0
# 5               assigned_room_type            0
# 6                  booking_changes            0
# 7                     deposit_type            0
# 8                            hotel            0
# 9           previous_cancellations            0
# 10            days_in_waiting_list            0
# 11                   customer_type            0
# 12                             adr            0
# 13     required_car_parking_spaces            0
# 14       total_of_special_requests            0
# 15              reservation_status            0
# 16  previous_bookings_not_canceled            0
# 17               is_repeated_guest            0
# 18                     is_canceled            0
# ...

# %%
# Visualizing the missing values
plt.bar(df_mv.Categories.values[:4],df_mv.Total_count.values[:4],align='center')
plt.title('Null values across columns')
plt.ylabel('total_counts')
plt.xlabel('categories')
# Out:
# Text(0.5, 0, 'categories')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **The dataset is about the HOTEL BOOKINGS.It contains informations like hotel types,arrival and departure schedules,country orgins,no of guests,lead time,average daily rates of hotel types etc.This dataset has some duplicate and missing values as well.**

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month   meal country market_segment  \
# count        87396              87396  87396   86944          87396
# unique           2                 12      5     177              8
# top     City Hotel             August     BB     PRT      Online TA
# freq         53428              11257  67978   27453          51618
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                 87396              87396              87396
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  69141              56552              46313
#
#        deposit_type customer_type reservation_status reservation_status_date
# count         87396         87396              87396                   87396
# unique            3             4                  3                     926
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *   **Hotel**: Type of hotel(City or Resort)
#
# *   **is_cancelled**: If the booking was cancelled then represented as (1) if not then represented as (0)
#
# *   **lead_time**: Number of days before the actual arrival of the guests
#
# *   **arrival_date_year** : Year of arrival date
#
# *   **arrival_date_month** : Month of month arrival date
#
# *   **arrival_date_week_number** : Week number of year for arrival date
# *   **arrival_date_day_of_month** : Day of arrival date
#
# *   **stays_in_weekend_nights** : Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
# *   **stays_in_week_nights** : Number of weeknights (Monday to Friday) spent at the hotel by the guests.
#
#
#
#
# *   **adults** : Number of adults among guests
# *   **children** : Number of children among guests
# *   **babies** : Number of babies among guests
#
# *   **meal** : Type of meal booked
#
# *   **country** : Countries from where the guests arrived
#
# *   **market_segment** : Designation of market segment
#
# *   **distribution_channel** : Name of booking distribution channel
# *    **is_repeated_guest** : If the booking was from a repeated guest then represented as (1) if not then represented as (0)
#
# *   **previous_cancellations** : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# *   **previous_bookings_not_canceled** : Number of previous bookings not cancelled by the customer prior to the current booking
#
# *   **reserved_room_type** : Type of room type reserved
#
# *   **assigned_room_type** : Type of room type assigned
#
# *   **booking_changes** : Number of changes made in the booking
#
# *   **deposit_type** : Deposit type
#
# *   **agent** : ID of travel agent who made the booking
#
# *   **company** : ID of the company that made the booking
#
# *   **days_in_waiting_list** : Number of days the booking was in the waiting list
#
# *   **customer_type** : Type of customer
# *   **adr** : Average Daily Rate is defined as average revenue earned for an occupied room on a given day
#
# *   **required_car_parking_spaces** : If car parking is required
#
# *   **total_of_special_requests** : Number of special requests made by the customer
#
# *   **reservation_status** : Reservation status (Cancelled, Check-Out or No-Show)
#
# *   **reservation_status_date** : Date of specific status

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.apply(lambda col:col.nunique()).reset_index().rename(columns={0:'T_count','index':'variables'})
# Out:
#                          variables  T_count
# 0                            hotel        2
# 1                      is_canceled        2
# 2                        lead_time      479
# 3                arrival_date_year        3
# 4               arrival_date_month       12
# 5         arrival_date_week_number       53
# 6        arrival_date_day_of_month       31
# 7          stays_in_weekend_nights       17
# 8             stays_in_week_nights       35
# 9                           adults       14
# 10                        children        5
# 11                          babies        5
# 12                            meal        5
# 13                         country      177
# 14                  market_segment        8
# 15            distribution_channel        5
# 16               is_repeated_guest        2
# 17          previous_cancellations       15
# 18  previous_bookings_not_canceled       73
# 19              reserved_room_type       10
# ...

# %%
df.apply(lambda col:col.unique()).reset_index().rename(columns={0:'names','index':'variables'})
# Out:
#                          variables  \
# 0                            hotel
# 1                      is_canceled
# 2                        lead_time
# 3                arrival_date_year
# 4               arrival_date_month
# 5         arrival_date_week_number
# 6        arrival_date_day_of_month
# 7          stays_in_weekend_nights
# 8             stays_in_week_nights
# 9                           adults
# 10                        children
# 11                          babies
# 12                            meal
# 13                         country
# 14                  market_segment
# 15            distribution_channel
# 16               is_repeated_guest
# 17          previous_cancellations
# 18  previous_bookings_not_canceled
# 19              reserved_room_type
# 20              assigned_room_type
# 21                 booking_changes
# 22                    deposit_type
# 23                           agent
# 24                         company
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Make a copy of a dataset
df_copy = df.copy()

# %%
df_copy['children'].fillna(0,axis=0,inplace=True)

# %% [markdown]
# **Since there is just 4 null values in children columns to we replaced those null values with zero**.

# %%
# Write your code to make your dataset analysis ready.
df_copy['guests_num'] = df_copy['adults'] + df_copy['babies'] + df_copy['children']   
df_copy['total_stay'] = df_copy['stays_in_weekend_nights'] + df_copy['stays_in_week_nights'] 
df_copy['country'].fillna('others',axis=0,inplace=True)
df_copy['agent'].fillna('not given',axis=0,inplace=True)
df_copy.drop(['adults','babies','children','company'],axis=1,inplace=True)

# %%
df_copy.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# ...

# %% [markdown]
# **Checking null values across columns after performing some data wrangling**.

# %%
# Columns
df_copy.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'meal', 'country', 'market_segment',
#        'distribution_channel', 'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'guests_num',
#        'total_stay'],
#       dtype='object')

# %%
# shape of dataset
df_copy.shape
# Out:
# (87396, 30)

# %%
df_copy.isnull().sum().sort_values(ascending=0)
# Out:
# hotel                             0
# is_canceled                       0
# guests_num                        0
# reservation_status_date           0
# reservation_status                0
# total_of_special_requests         0
# required_car_parking_spaces       0
# adr                               0
# customer_type                     0
# days_in_waiting_list              0
# agent                             0
# deposit_type                      0
# booking_changes                   0
# assigned_room_type                0
# reserved_room_type                0
# previous_bookings_not_canceled    0
# previous_cancellations            0
# is_repeated_guest                 0
# distribution_channel              0
# market_segment                    0
# country                           0
# meal                              0
# stays_in_week_nights              0
# stays_in_weekend_nights           0
# arrival_date_day_of_month         0
# arrival_date_week_number          0
# ...

# %%
# Filtering dataset
df_copy = df_copy[df_copy['adr']< 5000]

# %% [markdown]
# **There was a outliers in adr column so we performed some coding to filter it out.**

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1.   **I made a copy of a dataset to recover data in case of retrieving old records.**
# 2.   **There were some null values across four columns namely country,agents,children and company.I performed different operations for each column for replacing there null values.**
#
# 1.   **There were more than 80% null values in company column so I dropped that column from the dataset.**
# 2.   **For children column I replaced null values with zeros.**
#
# 1.   **For country column I replaced null values with string name others.**
# 2.     **For agent column I replaced null values with string name "not given".**
# 1.   **There was a outliers in adr column so we performed some coding to filter it out**.
#
# 1.   **I created two new columns i.e total stay,guests sum.**
# 2.   **To create total stay column,two numerical columns were added.**
#
# 1.   **To create guests sum column,three numerical columns were added.**

# %% [markdown]
# # ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ##  ***Most Preferred hotel type among guest***

# %%
# Filtering type of hotels
hotel_type = df_copy.hotel.value_counts().index
hotel_typeval = df_copy.hotel.value_counts().values
# Plotting pie chart
plt.style.use('seaborn')
plt.pie(hotel_typeval,labels=hotel_type,explode = (0, 0.1),autopct='%1.2f%%',colors = ['yellowgreen', 'lightcoral'])
plt.title('Most preffered hotel type',fontsize=20,color="maroon")
# Out:
# Text(0.5, 1.0, 'Most preffered hotel type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pie charts are used to show parts of a whole. A pie chart represents numbers in percentages, and the total sum of all the divided segments equals 100 percent.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **City hotel were most preffered over resort type hotel.More than 60% of guests booked city type hotel.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **City hotel can finds more services to attract more guests to increase more revenue.**
#
# **Resort hotel can find solution to attract guest and also find which facilities provided by city hotel to attract the guest.**

# %% [markdown]
# ## ***Most reserved room type among guest***

# %%
# grouping by reserved room type and find its count
room_type = df_copy.groupby('reserved_room_type').size().sort_values(ascending=False).reset_index().rename(columns={0:'T_count'})
room_type
# Out:
#   reserved_room_type  T_count
# 0                  A    56551
# 1                  D    17398
# 2                  E     6049
# 3                  F     2823
# 4                  G     2052
# 5                  B      999
# 6                  C      915
# 7                  H      596
# 8                  L        6
# 9                  P        6

# %%
# visualization code 
plt.style.use('seaborn')

# color pallete
colors = sns.color_palette('pastel')[0:9]
sns.set_theme(palette="dark", font_scale=1)
plt.pie(room_type['T_count'].values[0:5], labels = room_type['reserved_room_type'].values[:5], colors = colors, autopct='%.0f%%')
plt.title('Most preffered room type',fontsize=20,color="green")
# Out:
# Text(0.5, 1.0, 'Most preffered room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pie charts are used to show parts of a whole. A pie chart represents numbers in percentages, and the total sum of all the divided segments equals 100 percent.I use pie chart because pie chart gives simple and easy to understand picture that shows which hotel room type has more bookings.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **More than 65% of guests preffered 'A' type room and 'D' type room is booked by 20% of guests.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **A type rooms are most preferred rooms. This make positive impact on business.
# E,F,G type rooms are less preferred this insight makes neative impact.**

# %% [markdown]
# ## ***Top countries from which guests arrived***

# %%
# visualization code
country_count = df_copy['country'].value_counts().reset_index().rename(columns={'index':'countries','country':'visitors'})
top_country_visitors = country_count[:10]
top_country_visitors
# Out:
#   countries  visitors
# 0       PRT     27452
# 1       GBR     10433
# 2       FRA      8837
# 3       ESP      7252
# 4       DEU      5387
# 5       ITA      3066
# 6       IRL      3016
# 7       BEL      2081
# 8       BRA      1995
# 9       NLD      1911

# %%
# Bar Plot
plt.style.use('seaborn')
ax = sns.barplot(x='countries', y = 'visitors', data= top_country_visitors)
# Creating labels
ax.bar_label(ax.containers[0], fmt='%.1f')
plt.title('People from top 10 travelling countries')
# Out:
# Text(0.5, 1.0, 'People from top 10 travelling countries')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I have choose countplot to visualize guests origin country because countplot display the count of each observation for each category and here we have to represent countries vs guests count.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **I found that guests of origin belongings to Portugal were the most who did bookings.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Hotel should roll out offers improves hospitality to attract more guests for origin whose guests frequency were less.They should invests in online ads.**

# %% [markdown]
# ## ***Month wise hotel bookings across hotel types***

# %%
# month dictionary
month_dict = {'January':1,'February':2,'March':3, 'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}

# dataframe of monthwise bookings
month_wise_bookings= df_copy[['hotel','arrival_date_month']].value_counts().reset_index().rename(columns={0:'Visitors','arrival_date_month':'month'})



# mapping of month
month_wise_bookings=month_wise_bookings.sort_values('month', key = lambda x : x.apply (lambda x : month_dict[x]))
month_wise_bookings
# Out:
#            hotel      month  Visitors
# 23  Resort Hotel    January      1963
# 16    City Hotel    January      2730
# 19  Resort Hotel   February      2493
# 10    City Hotel   February      3605
# 5     City Hotel      March      4855
# 18  Resort Hotel      March      2657
# 3     City Hotel      April      5080
# 14  Resort Hotel      April      2828
# 2     City Hotel        May      5413
# 12  Resort Hotel        May      2942
# 4     City Hotel       June      5005
# 15  Resort Hotel       June      2760
# 1     City Hotel       July      5744
# 7   Resort Hotel       July      4313
# 0     City Hotel     August      6591
# 6   Resort Hotel     August      4666
# 8     City Hotel  September      4240
# 20  Resort Hotel  September      2450
# 9     City Hotel    October      4208
# 17  Resort Hotel    October      2726
# 22  Resort Hotel   November      2053
# 13    City Hotel   November      2942
# 21  Resort Hotel   December      2117
# 11    City Hotel   December      3014

# %%
plt.figure(figsize=(20,8))

#pltting lineplot on x- months & y- booking counts
sns.lineplot(x=month_wise_bookings['month'],y=month_wise_bookings['Visitors'],hue=month_wise_bookings['hotel'])

# set title for the plot
plt.title('Number of bookings across each month')
#set x label
plt.xlabel('Month')
#set y label
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A line chart reveals trends or change over time. Line charts can be used to show relationships within a continuous data set, and can be applied to a wide variety of categories, including daily number of visitors.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Most bookings were carried out from June till August.We found that bookings numbers started reducing we approached year ends.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **In order to increase hotel revenues in muted months,hotel should roll out offers to attract bookings.**

# %% [markdown]
# ## ***Percentage of booking cancelled***

# %%
# visualization code
is_cancelled = df_copy['is_canceled'].map({0:'No',1:'Yes'})
is_cancelled = is_cancelled.reset_index().drop(['index'],axis = 1)
is_cancelled.value_counts().reset_index().rename(columns={0:'count'})
# Out:
#   is_canceled  count
# 0          No  63371
# 1         Yes  24024

# %%
# plotting pie chart
plt.style.use('seaborn')
is_cancelled.value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20,colors = ['#99ff99','#ff9999'])
plt.title("Cancellation and Non Cancellation")
# Out:
# Text(0.5, 1.0, 'Cancellation and Non Cancellation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pie charts are used to show parts of a whole. A pie chart represents numbers in percentages, and the total sum of all the divided segments equals 100 percent.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **This dataset shows that only 27.5% of bookings got cancelled by the guests.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **We will analysis further to know the reasons behind cancellations in further analysis.**

# %% [markdown]
# ## ***Percentage of repeated guests***

# %%
# visualization code
repeated_guest = df_copy['is_repeated_guest'].map({0:'No',1:'Yes'})
repeated_guest = repeated_guest.reset_index().drop(['index'],axis = 1)
repeated_guest.value_counts().reset_index().rename(columns={0:'count'})
# Out:
#   is_repeated_guest  count
# 0                No  83980
# 1               Yes   3415

# %%
# bar plot for repeated and non-repeated guests
repeated_guest.value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20,colors = ['#ffcc99','#66b3ff'])
plt.title("Repeated and not repeated guests")
# Out:
# Text(0.5, 1.0, 'Repeated and not repeated guests')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pie charts are used to show parts of a whole. A pie chart represents numbers in percentages, and the total sum of all the divided segments equals 100 percent.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **More than 95% of bookings were done by guests who visited first time in hotel.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Hotel should get feedback from customers while check out from hotels and should provide some discounts upon revisiting hotels.**

# %% [markdown]
# ## ***Top agents which booked maximum hotels rooms***

# %%
# visualization code
# return highest bookings made by agents
highest_bookings= df_copy.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

 # as agent 0 was NAN value and we replaced it with 0 and indicates no bookings,so droping.
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True) 

# taking top 10 bookings made by agent
highest_bookings=highest_bookings[:10]

highest_bookings
# Out:
#          agent  Most_Bookings
# 8          9.0          28759
# 173      240.0          13028
# 333  not given          12193
# 13        14.0           3349
# 6          7.0           3300
# 182      250.0           2779
# 174      241.0           1644
# 26        28.0           1502
# 7          8.0           1383
# 0          1.0           1232

# %%
#Visualizaing the graph

plt.figure(figsize=(18,8))
sns.barplot(x=highest_bookings['agent'],y=highest_bookings['Most_Bookings'],order=highest_bookings['agent'])
plt.xlabel('Agent No')
plt.ylabel('Number of Bookings')
plt.title("Most Bookings Made by the agent")
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the agent')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I have choose barplot to visualize agents with highest bookings because barplot display the count of each observation for each category and here we have to represent agents vs booking count.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **We got know agent no 9 got most bookings of more than 25000.And agent nos (8,1,6) got least bookings.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Hotel should find reasons why such huge difference in bookings among agents and rectify it and this would help them in increasing there bookings.**

# %% [markdown]
# ## ***Percentage distribution of required_car_parking_spaces***

# %%
df_copy['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%',shadow=False,figsize=(12,6),fontsize=15,labels=None)

labels=df_copy['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **This pie chart showing the percentages of guests requiring car parking spaces.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Majority of guests don't requires parking spaces.Less than 10% of guests opted for car parking.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ## ***Distribution of customer types***

# %%
# visualization code
df_customer_type = pd.DataFrame(df_copy['customer_type'])
df_customer_type=df_customer_type.value_counts().reset_index().rename(columns={0:'Count'})
df_customer_type
# Out:
#      customer_type  Count
# 0        Transient  71985
# 1  Transient-Party  11727
# 2         Contract   3139
# 3            Group    544

# %%
# Bar plot visualisation
sns.barplot(x='customer_type', y='Count', data= df_customer_type)
plt.title('Guests Types')
# Out:
# Text(0.5, 1.0, 'Guests Types')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I have choose countplot to customers type because countplot display the count of each observation for each category and here we have to represent customer type and its count booking count.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Transient guests are one of the major market segments an consist of individuals or groups.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **They are walk-in guests, last minute or bookers or simply people that require a very short term stay in hotels.So hotel should reserve more rooms for these customer types to earn more revenues.**

# %% [markdown]
# ## ***Percentages of guests who made changes to their previous bookings***

# %%
# visualization code
df_copy['booking_changes	'] = np.where((df_copy['booking_changes'] >0),'Yes','No')
df_booking_changes=df_copy['booking_changes	'].value_counts().reset_index().rename(columns={'index':'opted','booking_changes\t':'count'})
df_booking_changes
# Out:
#   opted  count
# 0    No  71494
# 1   Yes  15901

# %%
# Plotting pie chart
plt.style.use('seaborn')

# color pallete
colors = sns.color_palette('pastel')[0:2]
sns.set_theme(palette="dark", font_scale=1)
plt.pie(df_booking_changes['count'].values[0:5], labels = df_booking_changes['opted'].values, colors = colors, autopct='%.0f%%')
plt.title('Percentage of guests that made changes to bookings',fontsize=20,color="green")
# Out:
# Text(0.5, 1.0, 'Percentage of guests that made changes to bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pie charts are used to show parts of a whole. A pie chart represents numbers in percentages, and the total sum of all the divided segments equals 100 percent.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **There were less than 20% of guests who made booking changes for hotels.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Since booking changes are not that much high so it would not lead to negative growth.So actions needed as of now.**

# %% [markdown]
# ## ***Distribution of deposit type***

# %%
# visualization code
df_copy.groupby('deposit_type').size().plot(kind='pie', explode=(0.5,0.5,0.05),autopct='%1.1f%%',shadow=False,figsize=(6,6),fontsize=20,labels=None,colors=['tomato', 'cornflowerblue', 'gold'])

# plotting pie chart
plt.title("% Distribution of deposit type",fontsize=20)
labels=df_copy['deposit_type'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Pie charts are used to show parts of a whole. A pie chart represents numbers in percentages, and the total sum of all the divided segments equals 100 percent.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Almost 98% guests prefer to pay the amount at hotels.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Hotel should encourage them to pay them online by offerings some cashback points to guests which can be redeemed in future.And may this will help reducing cancellations further.**

# %% [markdown]
# ## ***Types of meals preferred by guests***

# %%
# visualization code
df_copy['meal'].value_counts()[0:3].reset_index()
# Out:
#   index   meal
# 0    BB  67977
# 1    SC   9481
# 2    HB   9085

# %%
# plotting countplot
plt.figure(figsize=(18,8))
sns.countplot(x=df['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **The reason for picking this bar plot because meals types are divided into 5 categories which can be analysed very easily by using this chart.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Large no of guests prefer breakfast and dinner in hotels.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Hotel should plan in such way to avoid losses of food and preparing cost in order to increase revenues.**

# %% [markdown]
# ## ***Distribution of various channels through which bookings were made***

# %%
#Creating labels
labels=df_copy['distribution_channel'].value_counts().index.tolist()

# creating new df of distribution channel
df_dist_chnl=df_copy['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})

#adding percentage columns
df_dist_chnl['percent'] = round(df_dist_chnl['count']*100/df.shape[0],2)

#Creating list of percentage
sizes=df_dist_chnl['percent'].values.tolist()

#plotting the piw chart
df_copy['distribution_channel'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], shadow=False, figsize=(7,7),fontsize=10,labels=None)   

# setting legends with the percentage values
labels = [f'{l}, {s}%' for l, s in zip(labels, sizes)]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.title('Distribution Channel for Hotel Bookings')
# Out:
# Text(0.5, 1.0, 'Distribution Channel for Hotel Bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **This pie chart differentiates between different booking channels which is shown in form of percentage.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Most of the bookings were done through travel agent either online or offline.There were very less no of bookings done either direct or through corporate companies.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Travel agents carried out most bookings which is fair enough which I think it does'nt have any relations with growth prospects.**

# %% [markdown]
# ## ***Mean ADR distribution across hotel types***

# %%
# visualization code
df_adr = df_copy.groupby('hotel')['adr'].mean().reset_index()
df_adr
# Out:
#           hotel         adr
# 0    City Hotel  110.886949
# 1  Resort Hotel   99.025346

# %%
# Plot the graph
df_adr.plot(x="hotel", y="adr", kind="bar",title='Avg ADR distribution across hotel type',color=(0.1, 0.1, 0.1, 0.1),edgecolor='red')
# Out:
# <Axes: title={'center': 'Avg ADR distribution across hotel type'}, xlabel='hotel'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **This bar chart will help us to visualise more easily about ADR w.r.t hotel types**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **City hotel has more avg ADR while resort hotel has less avg ADR which tells us that city hotels are dearer to maintain as compare to resort hotels.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **With the insight found by visualising graph hotel management should take proper steps in reducing Avg ADR in order to attract more bookings in muted months to increase their revenues.**

# %% [markdown]
# ## ***Mean ADR distribution w.r.t to hotel types across different months***

# %%
# visualization code
df_Adr_dist=df_copy.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index().rename(columns={'arrival_date_month':'Month','hotel':'Hotel Type','adr':'ADR'})

month_dict = {'January':1,'February':2,'March':3, 'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}
df_Adr_dist=df_Adr_dist.sort_values('Month', key = lambda x : x.apply (lambda x : month_dict[x]))
df_Adr_dist
# Out:
#         Month    Hotel Type         ADR
# 8     January    City Hotel   85.092612
# 9     January  Resort Hotel   49.131584
# 6    February    City Hotel   88.945304
# 7    February  Resort Hotel   54.081107
# 15      March  Resort Hotel   57.569213
# 14      March    City Hotel   93.670639
# 0       April    City Hotel  117.156250
# 1       April  Resort Hotel   79.283805
# 17        May  Resort Hotel   80.551101
# 16        May    City Hotel  127.851240
# 13       June  Resort Hotel  112.340141
# 12       June    City Hotel  123.836342
# 11       July  Resort Hotel  156.166914
# 10       July    City Hotel  120.055385
# 3      August  Resort Hotel  187.566659
# 2      August    City Hotel  124.901601
# 22  September    City Hotel  118.546566
# 23  September  Resort Hotel  100.892331
# 20    October    City Hotel  107.304166
# 21    October  Resort Hotel   63.676313
# 18   November    City Hotel   89.454120
# 19   November  Resort Hotel   48.823434
# ...

# %%
# set plot size and plot the line
plt.figure(figsize=(20,8))
sns.lineplot(x=df_Adr_dist['Month'],y=df_Adr_dist['ADR'],hue=df_Adr_dist['Hotel Type'])

# set lables
plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **This line shows month on month ADR varying rates among hotel types.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ADR is directly proportional to bookings count in resort hotel types but it is not in case of city hotel.ADR does not vary much in city hotel type.It means there is high occupancy in resort hotel during June,July and August.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **With the gained insight resort hotel should take market feedback and work on it of have low occupancy during other months.And this is leading to their negative growth.**

# %% [markdown]
# ## ***Optimal stay in both hotel types***

# %%
# visualization code
hotel_stay=df_copy[['total_stay','hotel']].groupby(['hotel','total_stay']).size().reset_index().rename(columns={'hotel':'Hotel_Type',0:'count'})
hotel_stay
# Out:
#       Hotel_Type  total_stay  count
# 0     City Hotel           0    288
# 1     City Hotel           1  10283
# 2     City Hotel           2  10824
# 3     City Hotel           3  13552
# 4     City Hotel           4   9620
# ..           ...         ...    ...
# 71  Resort Hotel          45      1
# 72  Resort Hotel          46      1
# 73  Resort Hotel          56      2
# 74  Resort Hotel          60      1
# 75  Resort Hotel          69      1
#
# [76 rows x 3 columns]

# %%
# set plot size and plot barchart
plt.style.use('seaborn')

plt.figure(figsize=(18,9))
sns.barplot(x='total_stay',y='count',hue='Hotel_Type',data=hotel_stay,palette='YlOrRd')
plt.legend(loc='upper right')

#set labels
plt.title('Optimal Stay Length in Both hotel types')
plt.ylabel('Count')
plt.xlabel('Total_Stay in days')
# Out:
# Text(0.5, 0, 'Total_Stay in days')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **This bar chart is well suited for displaying information of total stay by a guests.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Maximum guests prefer to stay upto 3 days in city type hotel and upto 1-3 days in resort type hotels.**

# %% [markdown]
# ## ***Market Segment Contribution to ADR***

# %%
# visualization code
adr_cont = df_copy[['market_segment','adr']].groupby(['market_segment'])['adr'].mean().reset_index()
adr_cont
# Out:
#   market_segment         adr
# 0       Aviation  100.170396
# 1  Complementary    3.049245
# 2      Corporate   68.151246
# 3         Direct  116.579429
# 4         Groups   74.864284
# 5  Offline TA/TO   81.381254
# 6      Online TA  118.171606
# 7      Undefined   15.000000

# %%
# Create bars with different colors
plt.figure(figsize=(12,6))

plt.bar('market_segment','adr',data=adr_cont)
plt.title('Market Segment Contribution to ADR')
plt.ylabel('ADR')
plt.xlabel('Market Segments')
# Out:
# Text(0.5, 0, 'Market Segments')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **This bar plot clearly shows the ADR distribution across different categories which makes it easy to understand the pattern.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Online travel agent and direct type both contribute equally to ADR while aviation types come next in the category.**

# %% [markdown]
# ## ***Average Lead Time for each Hotel type***

# %%
# visualization code
df_avg_leadtime = df_copy[['hotel','lead_time']].groupby('hotel')['lead_time'].mean().reset_index()
df_avg_leadtime
# Out:
#           hotel  lead_time
# 0    City Hotel  77.679319
# 1  Resort Hotel  83.371938

# %%
# Plotting bar plot
sns.set_theme(style="whitegrid", palette="pastel")

sns.barplot(x=df_avg_leadtime['hotel'],y=df_avg_leadtime['lead_time'])
# set lables
plt.xlabel('Hotel type')
plt.ylabel('Average Lead time')
plt.title("Average Lead Time for each Hotel type")
# Out:
# Text(0.5, 1.0, 'Average Lead Time for each Hotel type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **This start groups different hotel type to represent the lead time amongs both hotels.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Booking or Reservation Lead Time is the period of time (most typically measured in calendar days) between when a guest makes the reservation and the actual check-in/arrival date.We finds here that resort type hotel has more lead time as compare to city type hotel.**

# %% [markdown]
# ## ***Average Wait Time for each Hotel type***

# %%
# visualization code
df_avg_waitingtime = df_copy[['hotel','days_in_waiting_list']].groupby('hotel')['days_in_waiting_list'].mean().reset_index()
df_avg_waitingtime
# Out:
#           hotel  days_in_waiting_list
# 0    City Hotel              1.020252
# 1  Resort Hotel              0.323834

# %%
# Plotting bar plot
sns.set_theme(style="ticks", palette="dark")
sns.set_style("darkgrid")
sns.barplot(x=df_avg_waitingtime['hotel'],y=df_avg_waitingtime['days_in_waiting_list'],palette='PRGn')
# set lables
plt.xlabel('Hotel type')
plt.ylabel('Average Wait time')
plt.title("Average Wait Time for each Hotel type")
# Out:
# Text(0.5, 1.0, 'Average Wait Time for each Hotel type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A barplot (or barchart) is one of the most common types of graphic. It shows the relationship between a numeric and a categoric variable. Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows city hotel has more lead time while resort hotel has less lead time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **City hotel should reduce their wait time in order to avoid cancellations of their bookings as guests generally cancels their bookings if wait time is more.**

# %% [markdown]
# ## ***ADR distribution across room types***

# %%
# visualisation of code
sns.boxplot(x = df_copy['assigned_room_type'], y = df_copy['adr'])
# Out:
# <Axes: xlabel='assigned_room_type', ylabel='adr'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Room type G and H has highest median ADR among all room types.While there are some outliers also in all room types.**

# %% [markdown]
# ## ***Relationship between Arriving Year, Leadtime and Cancellations***

# %%
# Pair Plot visualization code
plt.figure(figsize = (12,6), dpi=110)

# Plotting the graph by grouping by on is_canceled for comparison between Year and Lead Time
sns.barplot(x='arrival_date_year', y='lead_time', hue='is_canceled', data=df, palette='vlag')
plt.grid()
plt.title('Arriving Year, Leadtime and Cancellations')
plt.xlabel('Arrival Year')
plt.ylabel('Lead Time')
# Out:
# Text(0, 0.5, 'Lead Time')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **This bar plot showing the no of bookings and cancellation in their respective years.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The bookings are getting increased year on year while cancellations rates are also increasing.**

# %% [markdown]
# ## ***Correlation between cancellation and lead time***

# %%
# Pair Plot visualization code
df_lead_canc = df_copy.groupby("lead_time")['is_canceled'].describe()
sns.scatterplot(x=df_lead_canc.index, y=df_lead_canc["mean"] * 100)
plt.title('Correlation between cancellation and lead time', weight = 'bold')
plt.xlabel('Lead Time')
plt.ylabel('Mean (%)')
# Out:
# Text(0, 0.5, 'Mean (%)')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A scatter plot is a diagram where each value in the data set is represented by a dot.The seaborn module has a method for drawing scatter plots, it needs two arrays of the same length, one for the values of the x-axis, and one for the values of the y-axis.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **This scatter plot is shows more is the lead time,more the chances of the cancellations of bookings and vice versa.Lead time greater than 300 has the highest cancellations.**

# %% [markdown]
# ## ***Correlation Heatmap***

# %%
# Plotting correlations among different columns
corr_mat = df_copy.corr()
f, ax = plt.subplots(figsize=(14, 6))
sns.heatmap(corr_mat,annot=True,fmt='.2f', cmap="BuPu");

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A correlation heatmap is a heatmap that shows a 2D correlation matrix between two discrete dimensions, using colored cells to represent data from usually a monochromatic scale. The values of the first dimension appear as the rows of the table while of the second dimension as a column. The color of the cell is proportional to the number of measurements that match the dimensional value. This makes correlation heatmaps ideal for data analysis since it makes patterns easily readable and highlights the differences and variation in the same data. A correlation heatmap, like a regular heatmap, is assisted by a colorbar making data easily readable and comprehensible.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   **Lead Time vs Total stay = 0.32**
# 2.   **ADR vs guests number = 0.41**
# 1.   **Repeated guest vs booking not cancelled = 0.44**

# %% [markdown]
# # **5. Solution to Business Objective**

# %% [markdown]
# 1.   **Hotel can work on reducing wait time to avoid cancellations.**
# 2.   **Meals should properly designed to avoid wastage so as to bring the opoerations cost down.Same should be applicable for car parking spaces.**
#
# 1.   **Previously visited to give some offers for booking again in order to lure them because percentages to repeated guests are very less.**
# 2.   **Hotel should roll out offers in the month where bookings are low.**
#
# 1.   **Since most of the bookings are done through TA/TO,so hotel should coordinate with them more frequently to get feedback.**
# 2.   **Hotels should also work on their own booking portal to simply process and increase booking coun**ts

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.   **City hotels are the most preferred hotel type by the guests. We can say that city hotel is the busiest hotel.**
#
# 1.   **27.5 % bookings were got cancelled out of all the bookings.**
# 2.   **Only 3.9 % people were revisited the hotels. Rest 96.1 % were new guests. Thus retention rate is low.**
#
#
# 4.   **The percentage of 0 changes made in the booking was more than 82 %. Percentage of Single changes made was about 10%.**
#
# 1.   **79.1 % bookings were made through TA/TO (travel agents/Tour operators)**.
#
# 1.   **BB( Bed & Breakfast) is the most preferred type of meal by the guests.**
# 2.   **Maximum number of guests were from Portugal, i.e. more than 25000 guests.**
#
#
# 8.   **City hotel bookings count are more than resort hotel.**
#
# 1.   **Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.**
#
# 1.   **Booking cancellation rate is high for City hotels which almost 30 %.**
# 2.   **Average lead time for resort hotel is high.**
#
#
# 12.   **Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.**
#
# 1.   **Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week.**
# 2.   **Almost 19 % people did not cancel their bookings even after not getting the same room which they reserved while booking hotel. Only 2.5 % people cancelled the booking.**
#
# 15.   **Most of the customers (91.6%) do not require car parking spaces.**

# %% [markdown]
# # **Hurrah! You have successfully completed your EDA Capstone Project !!!**
